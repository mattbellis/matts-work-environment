# %% [markdown]
# # Grants

# %%
import matplotlib.pylab as plt
import numpy as np
import matplotlib.dates as mdates
import matplotlib.patches as mpatches


import sys

import datetime as dt
import pandas as pd

import seaborn as sns

#sns.set_style('darkgrid')

# %%
grants = []

# NSF - CMS
grant = {'funding_agency':'NSF', 'program1': 'EPP', 'program2':'RUI', \
        'external':True, 'role':'PI', 'coPIs':None, \
        'name':'PHY-1307562', 'title':'RUI: Searches for New Physics with the CMS Detector at the LHC', \
        'short_title':'CMS research', \
        'amount':204000, 'start':dt.datetime(2013,6,1), 'duration':dt.timedelta(days=3*365), 'funded':True, \
}
grants.append(grant)

grant = {'funding_agency':'NSF', 'program1': 'EPP', 'program2':'RUI', \
        'external':True, 'role':'PI', 'coPIs':None, \
        'name':'PHY-1608779', 'title':'RUI: Searches for New Physics with the CMS Detector at the LHC', \
        'short_title':'CMS research', \
        'amount':210333, 'start':dt.datetime(2016,6,1), 'duration':dt.timedelta(days=3*365), 'funded':True, \
}
grants.append(grant)

grant = {'funding_agency':'NSF', 'program1': 'EPP', 'program2':'RUI', \
        'external':True, 'role':'PI', 'coPIs':None, \
        'name':'PHY-1913923', 'title':'RUI: Searches for New Physics with the CMS Detector at the LHC', \
        'short_title':'CMS research', \
        'amount':201175, 'start':dt.datetime(2019,7,1), 'duration':dt.timedelta(days=3*365), 'funded':True, \
}
grants.append(grant)

grant = {'funding_agency':'NSF', 'program1': 'EPP', 'program2':'RUI', \
        'external':True, 'role':'PI', 'coPIs':None, \
        'name':'PHY-2310056', 'title':'RUI: Searches for New Physics with the CMS Detector at the LHC', \
        'short_title':'CMS research', \
        'amount':252000, 'start':dt.datetime(2023,8,1), 'duration':dt.timedelta(days=3*365), 'funded':True, \
}
grants.append(grant)

grant = {'funding_agency':'NSF', 'program1': 'EPP', 'program2':'RUI', \
        'external':True, 'role':'PI', 'coPIs':None, \
        'name':'PHY-292261', 'title':'RUI: Searches for New Physics with the CMS Detector at the LHC', \
        'short_title':'CMS research', \
        'amount':367_742, 'start':dt.datetime(2026,8,1), 'duration':dt.timedelta(days=3*365), 'funded':'Maybe', \
}
grants.append(grant)


# NSF - Dark Matter

grant = {'funding_agency':'NSF', 'program1': 'EPP', 'program2':'RUI', \
        'external':True, 'role':'PI', 'coPIs':'Kevin Rhoads', \
        'name':'PHY-XXX', 'title':'RUI: Searching for an annual modulation of naturally-occurring isotopes in atmospheric aerosols as an explanation for the DAMA-LIBRA dark matter signal', \
        'short_title':'Dark matter', \
        'amount':159598, 'start':dt.datetime(2019,8,1), 'duration':dt.timedelta(days=3*365), 'funded':False, \
}
grants.append(grant)


grant = {'funding_agency':'NSF/USCMS', 'program1': 'USCMS', 'program2':'USCMS Minigrants for outreach', \
        'external':True, 'role':'PI', 'coPIs':None, \
        'name':'PHY-XXX', 'title':'Summer workshop for high-school teachers where they will learn about CMS and build their own turn-key cloud chamber for use in their classrooms', \
        'short_title':'Cloud chamber workshop', \
        'amount':3840, 'start':dt.datetime(2015,1,1), 'duration':dt.timedelta(days=1.5*365), 'funded':True, \
}
grants.append(grant)



# APS

grant = {'funding_agency':'APS', 'program1': 'APS Outreach', 'program2':None, \
        'external':True, 'role':'PI', 'coPIs':None, \
        'name':'PHY-XXX', 'title':'Engaging the public with electronic cloud chambers', \
        'short_title':'Cloud chambers', \
        'amount':1920, 'start':dt.datetime(2013,8,1), 'duration':dt.timedelta(days=1.5*365), 'funded':False, \
}
grants.append(grant)

grant = {'funding_agency':'APS', 'program1': 'APS Outreach', 'program2':None, \
        'external':True, 'role':'PI', 'coPIs':None, \
        'name':'PHY-XXX', 'title':'Engaging the public with particle physics video games', \
        'short_title':'Particle physics video games', \
        'amount':10000, 'start':dt.datetime(2014,8,1), 'duration':dt.timedelta(days=1.5*365), 'funded':False, \
}
grants.append(grant)

grant = {'funding_agency':'APS', 'program1': 'APS Outreach', 'program2':None, \
        'external':True, 'role':'PI', 'coPIs':None, \
        'name':'PHY-XXX', 'title':'Engaging the public with particle physics video games', \
        'short_title':'Particle physics video games - II', \
        'amount':10000, 'start':dt.datetime(2015,8,1), 'duration':dt.timedelta(days=1.5*365), 'funded':False, \
}
grants.append(grant)

grant = {'funding_agency':'APS', 'program1': 'APS Outreach', 'program2':None, \
        'external':True, 'role':'PI', 'coPIs':None, \
        'name':'PHY-XXX', 'title':'Turn-key cloud chamber workshop for high-school teachers and instructional video', \
        'short_title':'Cloud chamber workshop', \
        'amount':10687, 'start':dt.datetime(2016,8,1), 'duration':dt.timedelta(days=1.5*365), 'funded':False, \
}
grants.append(grant)

grant = {'funding_agency':'APS', 'program1': 'APS Outreach', 'program2':None, \
        'external':True, 'role':'PI', 'coPIs':None, \
        'name':'PHY-XXX', 'title':'Turn-key cloud chamber instructional video', \
        'short_title':'Cloud chamber video', \
        'amount':9712, 'start':dt.datetime(2017,8,1), 'duration':dt.timedelta(days=1.5*365), 'funded':True, \
}
grants.append(grant)

grant = {'funding_agency':'APS', 'program1': 'APS Outreach', 'program2':None, \
        'external':True, 'role':'PI', 'coPIs':"David Harris", \
        'name':'PHY-XXX', 'title':'Entanglement: a quantum mechanics board game', \
        'short_title':'Quantum board game', \
        'amount':9032, 'start':dt.datetime(2019,8,1), 'duration':dt.timedelta(days=1.5*365), 'funded':False, \
}
grants.append(grant)





grant = {'funding_agency':'APS', 'program1': 'Innovation Fund', 'program2':None, \
        'external':True, 'role':'PI', 'coPIs':'Jesse Thaler (MIT)', \
        'name':'PHY-XXX', 'title':'A particle physics workshop for theorists using CMS open data', \
        'short_title':'Open data workshop for theorists', \
        'amount':25000, 'start':dt.datetime(2019,8,1), 'duration':dt.timedelta(days=2*365), 'funded':False, \
}
grants.append(grant)

grant = {'funding_agency':'APS', 'program1': 'Innovation Fund', 'program2':None, \
        'external':True, 'role':'PI', 'coPIs':'Gigi Gatewood (Siena), Jesse Moya (Siena), Jen Pendleton (Siena)', \
        'name':'PHY-XXX', 'title':'Bringing the Quantum Party to middle- and high-school classrooms!', \
        'short_title':'Quantum party for classrooms', \
        'amount':87000, 'start':dt.datetime(2022,8,1), 'duration':dt.timedelta(days=2*365), 'funded':False, \
}
grants.append(grant)


# AAPT
grant = {'funding_agency':'AAPT', 'program1': 'Bauder Fund', 'program2':None, \
        'external':True, 'role':'PI', 'coPIs':None, \
        'name':'PHY-XXX', 'title':'Running a turn-key cloud chamber workshop for high-school teachers at the 2017 AAPT Summer Meeting', \
        'short_title':'AAPT cloud chamber workshop', \
        'amount':10687, 'start':dt.datetime(2016,8,1), 'duration':dt.timedelta(days=2*365), 'funded':False, \
}
grants.append(grant)

grant = {'funding_agency':'AAPT', 'program1': 'Bauder Fund', 'program2':None, \
        'external':True, 'role':'PI', 'coPIs':None, \
        'name':'PHY-XXX', 'title':'The development, testing, and dissemination of a quantum mechanics board game', \
        'short_title':'Quantum board game', \
        'amount':550, 'start':dt.datetime(2018,8,1), 'duration':dt.timedelta(days=2*365), 'funded':True, \
}
grants.append(grant)


grant = {'funding_agency':'Fermilab', 'program1': 'Guests and Visitors program', 'program2':None, \
        'external':True, 'role':'PI', 'coPIs':None, \
        'name':'PHY-XXX', 'title':'Support to facilitate CMS Open Data Workshop', \
        'short_title':'First CMS Open Data Workshop', \
        'amount':2000, 'start':dt.datetime(2020,7,1), 'duration':dt.timedelta(days=0.5*365), 'funded':True, \
}
grants.append(grant)

grant = {'funding_agency':'Fermilab', 'program1': 'Guests and Visitors program', 'program2':None, \
        'external':True, 'role':'PI', 'coPIs':'Vincenzo Morina', \
        'name':'PHY-XXX', 'title':'Support to facilitate CMS Open Data Workshop', \
        'short_title':'Fourth CMS Open Data Workshop', \
        'amount':4000, 'start':dt.datetime(2023,7,1), 'duration':dt.timedelta(days=0.5*365), 'funded':True, \
}
grants.append(grant)

grant = {'funding_agency':'NSF/DIANA-HEP', 'program1': 'Undergraduate fellowship', 'program2':None, \
        'external':True, 'role':'PI', 'coPIs':None, \
        'name':'PHY-XXX', 'title':'Finalizing {\sc h5hep}, a ROOT-like file format based on HDF5, targeted toward intermediate stages of big-data analysis and outreach', \
        'short_title':'hepfile', \
        'amount':6000, 'start':dt.datetime(2021,3,1), 'duration':dt.timedelta(days=0.5*365), 'funded':True, \
}
grants.append(grant)


###############################################
grant = {'funding_agency':'KITP', 'program1': 'KITP', 'program2':None, \
        'external':True, 'role':'PI', 'coPIs':'Tom McCauley', \
        'name':'PHY-XXX', 'title':'Open Data Workshop for Theorists (KITP)', \
        'short_title':'Open Data for Theorists', \
        'amount':20000, 'start':dt.datetime(2026,6,1), 'duration':dt.timedelta(days=1.1*365), 'funded':'Maybe', \
}
grants.append(grant)




#############################################
# Pandas stuff
#############################################
print("Building pandas stuf........")
df_dict = {}
for key in grants[0].keys():
    #print(key)
    df_dict[key] = []
df_dict['end'] = []

for grant in grants:
    #print(grant)
    for key in grant.keys():
        #print(key)
        df_dict[key].append(grant[key])
    df_dict['end'].append(grant['start'] + grant['duration'])

df = pd.DataFrame.from_dict(df_dict)


df

# %%
nrows = len(df)

plt.figure(figsize=(24,14),dpi=200)

for i in range(nrows):
    x = df.sort_values('start', ascending=False).iloc[i]
    #print(x)
    start = x['start']
    end = x['end']
    #y = f"{x['Course']} - {x['Course Title']}"
    #y = f"${str(x['amount']):<8s} {x['funding_agency']:6s}  {x['short_title']:>40s}"
    y = f"{x['funding_agency']:<12s}  {x['short_title']:<36s} {'$'+str(x['amount']):>12s} "
    print(y)

    funded = x['funded']
    amount = x['amount']
    linewidth=5
    fmt = 'o-'
    color = 'blue'
    alpha = 1
    
    if x['funding_agency'].find('NSF')==0:
        color = 'blue'
    elif x['funding_agency']=='APS':
        color = 'red'
    elif x['funding_agency']=='Fermilab':
        color = 'orange'
    elif x['funding_agency']=='AAPT':
        color = 'green'
    elif x['funding_agency']=='KITP':
        color = 'magenta'
        
        
    #linewidth = int(1e-4*float(x['amount']))
    #if linewidth < 5:
    #    linewidth = 5
    
    if amount > 200000:
        linewidth = 35
    elif 100000 < amount < 200000:
        linewidth = 25
    elif 50000 < amount < 100000:
        linewidth = 15
    elif 10000 < amount < 50000:
        linewidth = 10
    elif amount < 10000:
        linewidth = 5
    
    #if funded==True:
    #    color='blue'
    #else:
    #    alpha = 0.3
    
    if funded==True:
        pts = plt.plot([start,end],[y,y],fmt,linewidth=linewidth, color=color, markersize=1, alpha=alpha)
    elif funded=='Maybe':
        pts = plt.plot([start,end],[y,y],fmt,linewidth=linewidth, color=color, markersize=1, alpha=0.2)
    else:
        pts = plt.plot([start],[y],'X',linewidth=linewidth, color=color, markersize=20, alpha=alpha)

    
plt.xlim(pd.Timestamp('2012-01-01'), pd.Timestamp('2030-09-01')) 
#plt.xlim(pd.Timestamp('2012-01-01'), pd.Timestamp('2016-01-01')) 

plt.grid(axis='both')

plt.tick_params(labelsize=18)

#plt.rcParams['font.family'] = 'font.monospace'
#plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['font.family'] = 'monospace'
plt.rcParams["font.monospace"] = ["FreeMono"]
plt.rcParams["font.monospace"] = ["Noto Mono"]

plt.tick_params(axis='x', labelsize=24)
plt.tick_params(axis='y', labelsize=18)




## Sabbatical
#plt.plot([pd.Timestamp('2018-06-15'),pd.Timestamp('2018-06-15')],[0,26],'k--')
#plt.plot([pd.Timestamp('2019-09-01'),pd.Timestamp('2019-09-01')],[0,26],'k--')
#plt.gca().text(pd.Timestamp('2019-01-01'), 10, r'SABBATICAL', fontsize=23, rotation=90)


###########################################################################################
# Custom legend
# https://matplotlib.org/stable/gallery/text_labels_and_annotations/custom_legends.html

#'''
custom_lines = [plt.Line2D([0], [0], color='blue', lw=8),
                plt.Line2D([0], [0], color='red', lw=8),
                plt.Line2D([0], [0], color='green', lw=8),
                plt.Line2D([0], [0], color='orange', lw=8),
                plt.Line2D([0], [0], color='black', lw=35),
                plt.Line2D([0], [0], color='black', lw=25),
                plt.Line2D([0], [0], color='black', lw=15),
                plt.Line2D([0], [0], color='black', lw=10),
                plt.Line2D([0], [0], color='black', lw=5),
                plt.Line2D([0], [0], marker='X', color='black', markersize=20, lw=0),
               ]
  
plt.legend(custom_lines,['NSF', 'APS', 'AAPT', 'Fermilab', f'   >$200000\n', \
                         f'   \$100000 - \$200000\n', \
                         f'   \$50000 - \$100000\n', 
                         f'   \$10000 - \$50000\n', 
                         f'   < \$10000\n', 
                        f'Not funded'], fontsize=18, loc='upper right')
#'''

plt.ylim(-1, 19)

plt.tight_layout()


plt.savefig('grant_activity.png')

# %%
mask = df['funded'] == True

df['amount'][mask].sum()

# %%
df.columns

# %%
# Pretty print for LaTeX

nrows = len(df)

output = ""
for i in range(nrows):
    dftmp = df.iloc[i]
    agency = dftmp['funding_agency']
    p1 = dftmp['program1']
    p2 = dftmp['program2']
    coPIs = dftmp['coPIs']
    
    if coPIs is None:
        coPIs = ""
    
    title = dftmp['title']
    amount = dftmp['amount']
    funded = dftmp['funded']
    start = dftmp['start']
    
    #print(funded)
            
    if funded == True:
        funded = "Yes"
    else:
        funded = ""
    #print(funded)
    
    output += f"{title} & {agency} & \${amount} & {coPIs} & {start:%d/%m/%Y} & {funded} \\\\\n"
    
print(output)

outfile = open("grants_table.tex",'w')
outfile.write(output)
outfile.close()

# %% [markdown]
# # Sandbox

# %%
################################################################################
################################################################################
def term2date(term):

    year = 2000 + int(term[1:])
    monthstart = 1
    monthend = 5
    daystart = 15
    dayend = 1
    if term[0] == 'F':
        monthstart = 9
        monthend = 12
        daystart = 1
        dayend = 1
    day = 15
    year = 2000 + int(term[1:])
    start = dt.datetime(year, monthstart, daystart, 0, 0)
    end = dt.datetime(year, monthend, dayend, 0, 0)

    return start,end

################################################################################

grants = []

grant = {'institution':'Siena College','funding_agency':'NSF', 'program1': 'EPP', 'program2':'RUI', \
        'external':True, 'role':'PI, CO-PI, contributor', 'coPIs':None, \
        'name':'PHY-XXXXX', 'title':'RUI: Searches for New Physics with the CMS Detector at the LHC', \
        'short_title':'CMS stuff', \
        'amount':204000, 'start':dt.datetime(2013,6,1), 'duration':dt.timedelta(days=3*365), 'funded':True, \
        'long_description':'ddddddddddddddd', \
        'short_description':'ddddddddddddddd'}
grants.append(grant)

grant = {'institution':'Siena College','funding_agency':'NSF', 'program1': 'EPP', 'program2':'RUI', \
        'external':True, 'role':'PI, CO-PI, contributor', 'coPIs':None, \
        'name':'PHY-YYYYY', 'title':'RUI: Searches for New Physics with the CMS Detector at the LHC', \
        'short_title':'CMS stuff', \
        'amount':209000, 'start':dt.datetime(2016,6,1), 'duration':dt.timedelta(days=3*365), 'funded':True, \
        'long_description':'ddddddddddddddd', \
        'short_description':'ddddddddddddddd'}
grants.append(grant)

grant = {'institution':'Siena College','funding_agency':'NSF', 'program1': 'EPP', 'program2':'RUI', \
        'external':True, 'role':'PI, CO-PI, contributor', 'coPIs':None, \
        'name':'PHY-ZZZZ', 'title':'RUI: Searches for New Physics with the CMS Detector at the LHC', \
        'short_title':'CMS stuff', \
        'amount':213000, 'start':dt.datetime(2019,6,1), 'duration':dt.timedelta(days=3*365), 'funded':True, \
        'long_description':'ddddddddddddddd', \
        'short_description':'ddddddddddddddd'}
grants.append(grant)

grant = {'institution':'Siena College','funding_agency':'NSF', 'program1': 'EPP', 'program2':'RUI', \
        'external':True, 'role':'PI, CO-PI, contributor', 'coPIs':None, \
        'name':'PHY-MMMM', 'title':' RUI: Searching for an annual modulation of naturally-occurring isotopes in atmospheric aerosols as an explanation for the DAMA-LIBRA dark matter signal', \
        'short_title':'Dark matter', \
        'amount':170000, 'start':dt.datetime(2019,8,1), 'duration':dt.timedelta(days=3*365), 'funded':False, \
        'long_description':'ddddddddddddddd', \
        'short_description':'ddddddddddddddd'}
grants.append(grant)

grant = {'institution':'Siena College','funding_agency':'NSF', 'program1': 'EPP', 'program2':'RUI', \
        'external':True, 'role':'PI, CO-PI, contributor', 'coPIs':None, \
        'name':'PHY-ZZZZ', 'title':'RUI: Searches for New Physics with the CMS Detector at the LHC', \
        'short_title':'CMS stuff', \
        'amount':640000, 'start':dt.datetime(2022,6,1), 'duration':dt.timedelta(days=3*365), 'funded':False, \
        'long_description':'ddddddddddddddd', \
        'short_description':'ddddddddddddddd'}
grants.append(grant)


grant = {'institution':'Siena College','funding_agency':'AAPT', 'program1': 'Bauder Fund', 'program2':None, \
        'external':True, 'role':'PI', 'coPIs':None, \
        'name':'Quantum Party', 'title':'A research', \
        'short_title':'Quantum party', \
        'amount':550, 'start':dt.datetime(2019,1,1), 'duration':dt.timedelta(days=365), 'funded':True, \
        'long_description':'ddddddddddddddd', \
        'short_description':'ddddddddddddddd'}
grants.append(grant)

grant = {'institution':'Siena College','funding_agency':'APS', 'program1': 'Innovation Fund', 'program2':None, \
        'external':True, 'role':'PI', 'coPIs':None, \
        'name':'Workshop', 'title':'A research', \
        'short_title':'Quantum party', \
        'amount':40000, 'start':dt.datetime(2021,1,1), 'duration':dt.timedelta(days=365), 'funded':True, \
        'long_description':'ddddddddddddddd', \
        'short_description':'ddddddddddddddd'}
grants.append(grant)



print(grants)
ngrants = len(grants)

#############################################
# Pandas stuff
#############################################
print("Building pandas stuf........")
df_dict = {}
for key in grants[0].keys():
    print(key)
    df_dict[key] = []

for grant in grants:
    print(grant)
    for key in grant.keys():
        print(key)
        df_dict[key].append(grant[key])

df = pd.DataFrame.from_dict(df_dict)

#plt.figure()
#sns.catplot(data=df, y='name',x='start',hue='funding_agency',kind='bar')
#############################################

#plt.show()

print(grants)

colors = {'NSF - True':'blue', 'NSF - False':'cyan', 'APS':'red', 'CMS internal':'orange', 'AAPT':'green', 'CURCA':'yellow'}

# Sort by the dates
df.sort_values(by=['start'],inplace=True)
df

# %%
df['funded']

funded_hatch = np.ones(len(df),dtype=str)
mask = df['funded'] == True
funded_hatch[mask] = ''
funded_hatch[~mask] = 'O'

df['funded_hatch'] = funded_hatch


n = len(df)
vals = []
for i in range(n):
    x = df.iloc[i]['funding_agency'] + ' - ' + str(df.iloc[i]['funded'])
    vals.append(x)
    
df['agency_funded'] = vals

# %%
df

# %%
#df
print(df.columns)
df['amount']

# %%
df['funding_agency']

# %%
df['start']

# %%
type(df['start'][0])

# %%
x = pd.to_datetime(df['start'])

x

# %%
df.plot.bar(x='start',y='amount')

# %%
#? df.plot.bar

# %%
#? sns.barplot

# %%
#? plt.Rectangle

# %%
plt.figure(figsize=(12,4))

#sns.barplot(data=df, x='start', y='amount',hue='funding_agency')
sns.barplot(x=pd.to_datetime(df['start']), y=df['amount'],hue=df['agency_funded'],hatch=df['funded_hatch'])#,alpha=[1,1,1,1,0.2])

#plt.gca().get_xticks(rotation=90)
plt.gcf().autofmt_xdate(rotation=90)
#plt.gca().xaxis.set_major_formatter(mdates.DateFormatter("%b %Y"))
plt.yscale('log')
plt.ylim(1,300000)

plt.gca().xaxis

# %%
#? sns.barplot

# %%
plt.figure()
x = plt.Rectangle((1,1),5,5)

plt.gca().patches.append(x)

plt.xlim(0,10)
plt.ylim(0,10)

# %% [markdown]
# $$y_1 = N_0 e^{-k x_1}$$
#
# $$y_2 = N_0 e^{-k x_2}$$
#
# $$y_1 = N_0 e^{-k x_1}$$
# $$y_2 = N_0 e^{-k x_2}$$
#
# $$(y_1/y_2) = e^{-k x_1}/e^{-x k_2}$$
# $$(y_1/y_2) = e^{-k (x_2 - x_1)}$$
#
# $$\ln (y_1/y_2) = -k (x_2 - x_1)$$
# $$-\ln (y_1/y_2)/(x_2-x_1) = k$$

# %%
c_dict = {'NSF':'#E64646', 'CURCA':'#E69646', 'ENG':'#34D05C', 'APS':'#34D0C3', 'AAPT':'#3475D0'}

plt.figure(figsize=(12,8))
df.plot.scatter(x='start',y='amount',ax=plt.gca(), s=1)

for i in range(len(df)):

    x = df.iloc[i]['start']
    y = df.iloc[i]['amount']
    
    agency = df.iloc[i]['funding_agency']
    funded = df.iloc[i]['funded']
    dur = df.iloc[i]['duration']
    #print(dur.days)
    
    color = c_dict[agency]
    alpha=1.0
    hatch = ''
    linecolor = color
    facecolor = color
    linewidth = 5
    
    if funded==False:
        alpha = 0.8
        hatch = '/'
        linecolor = color
        facecolor = 'black'
        linewidth=5

    
    width = dt.timedelta(days=120)

    bar = plt.Rectangle((x,1),width,y,color=facecolor,alpha=alpha,ec=linecolor,linewidth=linewidth,hatch=hatch)
    plt.gca().patches.append(bar)

    if funded:
        dur = dt.timedelta(days=dur.days)
        #arrow =  mpatches.FancyArrowPatch((x+width, y/20), (x+dur, y/20),color='k',linestyle='-.', \
        #                                  mutation_scale=20)
        #plt.gca().patches.append(arrow)
        
        #print(x,width,dur)
        #print(x+width)
        #print(x+dur)
        #print(x+width+dur)
        # Points spaced 1 day apart
        
        # Exponential 
        '''
        lowval = 1000
        k = np.log(lowval/y)/(dur.days)
        print(k)
        xpts = np.arange(x+width,x+width+dur,dt.timedelta(days=1))
        ypts = y*np.exp(k*np.arange(0,dur.days,1))
        print(f"len(xpts): {len(xpts)}")
        print(f"len(ypts): {len(ypts)}")
        plt.plot(xpts,ypts,color=color)
        '''
        
        # Linear 
        lowval = 1
        xpts = [x+width,x+width+dur]
        ypts = [y,lowval]
        #print(ypts)
        #print(f"len(xpts): {len(xpts)}")
        #print(f"len(ypts): {len(ypts)}")
        #plt.plot(xpts,ypts,color=color)
        plt.fill_between(xpts,ypts,color=color,alpha=0.2)

    
    
#plt.yscale('log')
#plt.ylim(1,300000)
plt.ylabel('Amount ($)',fontsize=24)
plt.xlabel('Start date of grant',fontsize=24)
plt.xticks(fontsize=14);
plt.yticks(fontsize=14);

# %%
? plt.Rectangle
#? plt.fill_between

# %%
plt.figure(figsize=(12,4))
sns.scatterplot(data=df,x='start',y='amount')

# %%
df

# %%
################################################################################
# External
################################################################################

fig, ax = plt.subplots(figsize=(12,4))
grant_names = []
for i,grant in enumerate(grants):

    if grant['external'] is False:
        continue 

    #identifier = grant['identifier'][0]
    #identifier = '{0} - {1}'.format(grant['instances'][0]['name'],grant['identifier'][0])
    identifier = '{0} - {1}'.format(grant['name'],grant['start'].year)
    grant_names.append(identifier)
    print(identifier)

    start,end = grant['start'], grant['start'] + grant['duration']
    xranges = [(start,end-start)]
    yrange = (ngrants - i - 1,1.0)
    # Plot the broken horizontal bars
    print(xranges)
    fc = 'blue'
    if grant['funding_agency'] in colors.keys():
        fc = colors[grant['funding_agency']]

    alpha = 1.0
    if grant['funded']==False:
        alpha = 0.2
    plt.broken_barh(xranges, yrange, facecolors=fc, alpha=alpha)

#grant_names.reverse()
print(grant_names)
grant_names.reverse()
print(grant_names)
y_pos = np.arange(0,len(grants),1) + 0.5
ax.set_yticks(y_pos)
ax.set_yticklabels(grant_names)
plt.grid(axis='y')

ax.xaxis_date()
plt.tight_layout()


################################################################################
# Internal
#
# Stacked bar graph?
#
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.plot.bar.html
################################################################################

fig, ax = plt.subplots(figsize=(12,4))
grant_names = []
for i,grant in enumerate(grants):

    if grant['external'] is True:
        continue 

    #identifier = grant['identifier'][0]
    #identifier = '{0} - {1}'.format(grant['instances'][0]['name'],grant['identifier'][0])
    identifier = '{0} - {1}'.format(grant['name'],grant['start'].year)
    grant_names.append(identifier)
    print(identifier)

    start,end = grant['start'], grant['start'] + grant['duration']
    xranges = [(start,end-start)]
    yrange = (ngrants - i - 1,1.0)
    # Plot the broken horizontal bars
    print(xranges)
    fc = 'blue'
    if grant['funding_agency'] in colors.keys():
        fc = colors[grant['funding_agency']]

    alpha = 1.0
    if grant['funded']==False:
        alpha = 0.2
    plt.broken_barh(xranges, yrange, facecolors=fc, alpha=alpha)

#grant_names.reverse()
print(grant_names)
grant_names.reverse()
print(grant_names)
y_pos = np.arange(0,len(grants),1) + 0.5
ax.set_yticks(y_pos)
ax.set_yticklabels(grant_names)
plt.grid(axis='y')

ax.xaxis_date()
plt.tight_layout()

# %% [markdown]
# https://towardsdatascience.com/gantt-charts-with-pythons-matplotlib-395b7af72d72

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.patches import Patch
import numpy as np

# %%
df

# %%
# project start date
'''
proj_start = df.Start.min()
# number of days from project start to task start
df['start_num'] = (df.Start-proj_start).dt.days
# number of days from project start to end of tasks
df['end_num'] = (df.End-proj_start).dt.days
# days between start and end of each task
df['days_start_to_end'] = df.end_num - df.start_num
'''

# %%
#pd.to_datetime(df['duration'])

# %%
# create a column with the color for each type of grant
c_dict = {'NSF':'#E64646', 'CURCA':'#E69646', 'ENG':'#34D05C', 'APS':'#34D0C3', 'AAPT':'#3475D0'}

def color(row):
    return c_dict[row['funding_agency']]

df['color'] = df.apply(color, axis=1)

# %%
fig, ax = plt.subplots(1, figsize=(16,6))
ax.barh(df.name, df.duration, left=df.start, color=df.color, hatch='/')

legend_elements = [Patch(facecolor=c_dict[i], label=i)  for i in c_dict]
plt.legend(handles=legend_elements)

##### TICKS #####
#xticks = np.arange(0, 20000+1, 3)
#xticks_labels = pd.date_range(18000, end=20000).strftime("%m/%d")
#xticks_minor = np.arange(0, 20000+1, 1)
#ax.set_xticks(xticks)
#ax.set_xticks(xticks_minor, minor=True)
#ax.set_xticklabels(xticks_labels[::3])
