# %%
import numpy as np
import matplotlib.pylab as plt

# %matplotlib notebook

# %%
filetypes = ['ROOT','Text','Zipped text','HDF5','HDF5 compressed']

files = []
files.append({'name':'data.X','ROOTsize':14403501, 'ROOTspeed':4.8,
                           'Textsize':32619674, 'Textspeed':-1,
                           'Zipsize':12168467, 'Zipspeed':9.2, # Almost all reading in
                           'HDF5size':30677896,'HDFspeed':-1,
                           'HDF5compressedsize':8362708,'HDFcompressedspeed':15.5,'HDFcompressedspeed_select':4.9})

files.append({'name':'1M.X','ROOTsize':157018311, 'ROOTspeed':50,
                           'Textsize':656478527, 'Textspeed':-1,
                           'Zipsize':314206644, 'Zipspeed':111, # Almost all reading in
                           'HDF5size':335918672,'HDFspeed':-1,
                           'HDF5compressedsize':246280899,'HDFcompressedspeed':68,'HDFcompressedspeed_select':21})

# %%
#files

# %%
keys = files[0].keys()
sizekeys = []
for k in keys:
    if 'size' in k:
        sizekeys.append(k)
        
speedkeys = []
for k in keys:
    if 'speed' in k:
        speedkeys.append(k)
        
print(speedkeys)
# Out:
# ['ROOTspeed', 'Textspeed', 'Zipspeed', 'HDFspeed', 'HDFcompressedspeed', 'HDFcompressedspeed_select']

# %%
sizes = []
for k in sizekeys:
    sizes.append(files[0][k]/1e6)
print(sizes)

speeds = []
for k in speedkeys:
    s = files[0][k]
    if s>0:
        speeds.append(s)
print(speeds)

speednames = ['ROOT', 'Zipped text', 'HDF5 compressed', 'HDF5 compressed/curated']
# Out:
# [14.403501, 32.619674, 12.168467, 30.677896, 8.362708]
# [4.8, 9.2, 15.5, 4.9]

# %%
myformat = ['or','sk','sk','^b','^b']
print(colors)
plt.figure()
x = np.arange(0,len(sizes))
plt.xticks(x, filetypes,fontsize=12)
for xpt,s,f in zip(x,sizes,myformat):
    plt.plot(xpt,s,f,markersize=20)
plt.ylim(0,1.2*max(sizes))
plt.ylabel('Filesize (Mb)',fontsize=18)
plt.gca().set_xticklabels(plt.gca().xaxis.get_majorticklabels(), rotation=45)
plt.tight_layout()
# Out:
# ['r', 'r', 'r', 'b', 'b']
# <img src="data:image/png;base64,..." width="640">

# %%
myformat = ['or','sk','sk','^b','^b']
plt.figure()
x = np.arange(0,len(sizes))
plt.xticks(x, filetypes,fontsize=12)
for xpt,s,f in zip(x,sizes,myformat):
    plt.plot(xpt,s,f,markersize=20)
plt.ylim(0,1.2*max(sizes))
plt.ylabel('Filesize (Mb)',fontsize=18)
plt.gca().set_xticklabels(plt.gca().xaxis.get_majorticklabels(), rotation=45)
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
myformat = ['or','sk','^b','^b']
plt.figure()
x = np.arange(0,len(sizes))
plt.xticks(x, speednames,fontsize=12)
for xpt,s,f in zip(x,speeds,myformat):
    plt.plot(xpt,s,f,markersize=20)
plt.ylim(0,1.2*max(speeds))
plt.ylabel('Process time (seconds)',fontsize=18)
plt.gca().set_xticklabels(plt.gca().xaxis.get_majorticklabels(), rotation=45)
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # 1M events

# %%
sizes = []
for k in sizekeys:
    sizes.append(files[1][k]/1e6)
print(sizes)

speeds = []
for k in speedkeys:
    s = files[1][k]
    if s>0:
        speeds.append(s)
print(speeds)
# Out:
# [157.018311, 656.478527, 314.206644, 335.918672, 246.280899]
# [50, 111, 68, 21]

# %%
myformat = ['or','sk','sk','^b','^b']
plt.figure()
x = np.arange(0,len(sizes))
plt.xticks(x, filetypes,fontsize=12)
for xpt,s,f in zip(x,sizes,myformat):
    plt.plot(xpt,s,f,markersize=20)
plt.ylim(0,1.2*max(sizes))
plt.ylabel('Filesize (Mb)',fontsize=18)
plt.gca().set_xticklabels(plt.gca().xaxis.get_majorticklabels(), rotation=45)
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
myformat = ['or','sk','^b','^b']
plt.figure()
x = np.arange(0,len(sizes))
plt.xticks(x, speednames,fontsize=12)
for xpt,s,f in zip(x,speeds,myformat):
    plt.plot(xpt,s,f,markersize=20)
plt.ylim(0,1.2*max(speeds))
plt.ylabel('Process time (seconds)',fontsize=18)
plt.gca().set_xticklabels(plt.gca().xaxis.get_majorticklabels(), rotation=45)
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="640">
